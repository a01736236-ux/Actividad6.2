# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Importamos mi ciudad
data = pd.read_csv("Oporto_Portugal.csv")

# %%
#Verificamos información del DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14873 entries, 0 to 14872
# Data columns (total 52 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    14873 non-null  int64
#  1   id                            14873 non-null  int64
#  2   listing_url                   14873 non-null  object
#  3   last_scraped                  14873 non-null  object
#  4   source                        14873 non-null  object
#  5   name                          14873 non-null  object
#  6   description                   14525 non-null  object
#  7   neighborhood_overview         8342 non-null   object
#  8   picture_url                   14873 non-null  object
#  9   host_id                       14873 non-null  int64
#  10  host_url                      14873 non-null  object
#  11  host_name                     14873 non-null  object
#  12  host_since                    14873 non-null  object
#  13  host_location                 9862 non-null   object
#  14  host_about                    7817 non-null   object
#  15  host_response_time            12640 non-null  object
#  16  host_response_rate            12640 non-null  object
#  17  host_acceptance_rate          13178 non-null  object
#  18  host_is_superhost             14025 non-null  object
#  19  host_thumbnail_url            14873 non-null  object
#  20  host_picture_url              14873 non-null  object
#  21  host_neighbourhood            1128 non-null   object
#  22  host_listings_count           14873 non-null  int64
#  23  host_total_listings_count     14873 non-null  int64
#  24  host_verifications            14873 non-null  object
#  25  host_has_profile_pic          14873 non-null  object
#  26  host_identity_verified        14873 non-null  object
#  27  neighbourhood                 8342 non-null   object
#  28  neighbourhood_cleansed        14873 non-null  object
#  29  neighbourhood_group_cleansed  14873 non-null  object
#  30  latitude                      14873 non-null  float64
#  31  longitude                     14873 non-null  float64
#  32  property_type                 14873 non-null  object
#  33  room_type                     14873 non-null  object
#  34  accommodates                  14873 non-null  int64
#  35  bathrooms_text                14858 non-null  object
#  36  bedrooms                      14449 non-null  float64
#  37  beds                          13180 non-null  float64
#  38  amenities                     14873 non-null  object
#  39  price                         13189 non-null  object
#  40  minimum_nights                14873 non-null  int64
#  41  maximum_nights                14873 non-null  int64
#  42  minimum_minimum_nights        14871 non-null  float64
#  43  maximum_minimum_nights        14871 non-null  float64
#  44  minimum_maximum_nights        14871 non-null  float64
#  45  maximum_maximum_nights        14871 non-null  float64
#  46  minimum_nights_avg_ntm        14873 non-null  float64
#  47  maximum_nights_avg_ntm        14873 non-null  float64
#  48  calendar_updated              0 non-null      float64
#  49  has_availability              13995 non-null  object
#  50  availability_30               14873 non-null  int64
#  51  availability_60               14873 non-null  int64
# dtypes: float64(11), int64(10), object(31)
# memory usage: 5.9+ MB

# %%
#Corroboramos valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                          0
# id                                  0
# listing_url                         0
# last_scraped                        0
# source                              0
# name                                0
# description                       348
# neighborhood_overview            6531
# picture_url                         0
# host_id                             0
# host_url                            0
# host_name                           0
# host_since                          0
# host_location                    5011
# host_about                       7056
# host_response_time               2233
# host_response_rate               2233
# host_acceptance_rate             1695
# host_is_superhost                 848
# host_thumbnail_url                  0
# host_picture_url                    0
# host_neighbourhood              13745
# host_listings_count                 0
# host_total_listings_count           0
# host_verifications                  0
# host_has_profile_pic                0
# host_identity_verified              0
# neighbourhood                    6531
# neighbourhood_cleansed              0
# neighbourhood_group_cleansed        0
# latitude                            0
# longitude                           0
# property_type                       0
# room_type                           0
# accommodates                        0
# bathrooms_text                     15
# bedrooms                          424
# beds                             1693
# amenities                           0
# price                            1684
# minimum_nights                      0
# maximum_nights                      0
# minimum_minimum_nights              2
# maximum_minimum_nights              2
# minimum_maximum_nights              2
# maximum_maximum_nights              2
# minimum_nights_avg_ntm              0
# maximum_nights_avg_ntm              0
# calendar_updated                14873
# has_availability                  878
# availability_30                     0
# availability_60                     0
# dtype: int64

# %%
#Reemplazamos valores nulos del dataframe con "bfill"
data1 =data.fillna(method="bfill") 
data1
# Out:
# C:\Users\Jorge Cortés Sánchez\AppData\Local\Temp\ipykernel_21308\419970050.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1 =data.fillna(method="bfill")
#        Unnamed: 0                   id  \
# 0               0                41339
# 1               1                55111
# 2               2                73828
# 3               3                87873
# 4               4                94701
# ...           ...                  ...
# 14868       14868  1442944169953064519
# 14869       14869  1442949312063381006
# 14870       14870  1442972095274896534
# 14871       14871  1443457123327763296
# 14872       14872  1443457546151071185
#
#                                             listing_url last_scraped  \
# 0                    https://www.airbnb.com/rooms/41339   2025-06-28
# 1                    https://www.airbnb.com/rooms/55111   2025-06-26
# 2                    https://www.airbnb.com/rooms/73828   2025-06-26
# 3                    https://www.airbnb.com/rooms/87873   2025-06-26
# 4                    https://www.airbnb.com/rooms/94701   2025-06-27
# ...                                                 ...          ...
# 14868  https://www.airbnb.com/rooms/1442944169953064519   2025-06-27
# 14869  https://www.airbnb.com/rooms/1442949312063381006   2025-06-28
# 14870  https://www.airbnb.com/rooms/1442972095274896534   2025-06-26
# 14871  https://www.airbnb.com/rooms/1443457123327763296   2025-06-26
# 14872  https://www.airbnb.com/rooms/1443457546151071185   2025-06-27
#
#             source                                               name  \
# 0      city scrape                       Porto city flat near the sea
# 1      city scrape  Fontielas Houses |Floor1 in House with shared ...
# 2      city scrape  Fontielas Houses |Floor0 in House with shared ...
# 3      city scrape                           Oporto Apartment Triplex
# 4      city scrape                Big TERRACE APARTMENT / city center
# ...            ...                                                ...
# 14868  city scrape                            CC House Porto Serenity
# 14869  city scrape                                CC Rooms Porto Calm
# 14870  city scrape                        2 bedroom apart Casa Musica
# 14871  city scrape     Heart Of Porto Apartment E Duplex by Vacationy
# 14872  city scrape     Heart Of Porto Apartment F Duplex by Vacationy
#
#                                              description  \
# 0      Welcome to our apartment located near the sea ...
# 1      Is the first floor in a villa with shared pool...
# 2      Ground floor in a villa with shared pool and p...
# 3      - Cozy apartment with great sun exposition<br ...
# 4      Independent apartment with big and sunny terra...
# ...                                                  ...
# 14868  CC HOUSE offers an elegant environment in whit...
# 14869  CC Rooms offers an elegant ambiance in white a...
# 14870  Don't miss the opportunity of living in one of...
# 14871  New! Visit everything on foot! Tourist attract...
# 14872  New! Visit everything on foot! Tourist attract...
#
#                                    neighborhood_overview  \
# 0      In the surrounds you have Serralves Museum and...
# 1      OPorto Apartment Triplex is located on Rua San...
# 2      OPorto Apartment Triplex is located on Rua San...
# 3      OPorto Apartment Triplex is located on Rua San...
# 4      In the neighborhood we can find all type of se...
# ...                                                  ...
# 14868                                                NaN
# 14869                                                NaN
# 14870                                                NaN
# 14871                                                NaN
# 14872                                                NaN
#
#                                              picture_url    host_id  ...  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...     180050  ...
# 1      https://a0.muscache.com/pictures/b3c38006-5fdf...     259711  ...
# 2      https://a0.muscache.com/pictures/ffb19299-425c...     259711  ...
# 3      https://a0.muscache.com/pictures/33686513/c54f...     480980  ...
# 4      https://a0.muscache.com/pictures/812621/ab58f5...     505473  ...
# ...                                                  ...        ...  ...
# 14868  https://a0.muscache.com/pictures/hosting/Hosti...  695687907  ...
# 14869  https://a0.muscache.com/pictures/hosting/Hosti...  695687907  ...
# 14870  https://a0.muscache.com/pictures/miso/Hosting-...  110938864  ...
# 14871  https://a0.muscache.com/pictures/prohost-api/H...  452918929  ...
# 14872  https://a0.muscache.com/pictures/prohost-api/H...  452918929  ...
#
#       minimum_minimum_nights maximum_minimum_nights minimum_maximum_nights  \
# 0                        2.0                    2.0                 1125.0
# 1                        5.0                    7.0                   28.0
# 2                        5.0                    5.0                   28.0
# 3                        3.0                    3.0                   15.0
# 4                        3.0                    7.0                 1125.0
# ...                      ...                    ...                    ...
# 14868                    1.0                    1.0                  365.0
# 14869                    1.0                    1.0                  365.0
# 14870                    1.0                    1.0                  365.0
# 14871                    1.0                    2.0                 1125.0
# 14872                    1.0                    2.0                 1125.0
#
#       maximum_maximum_nights minimum_nights_avg_ntm maximum_nights_avg_ntm  \
# 0                     1125.0                    2.0                 1125.0
# 1                       28.0                    5.1                   28.0
# 2                       28.0                    5.0                   28.0
# 3                       15.0                    3.0                   15.0
# 4                     1125.0                    3.7                 1125.0
# ...                      ...                    ...                    ...
# 14868                  365.0                    1.0                  365.0
# 14869                  365.0                    1.0                  365.0
# 14870                  365.0                    1.0                  365.0
# 14871                 1125.0                    2.0                 1125.0
# 14872                 1125.0                    2.0                 1125.0
#
#       calendar_updated has_availability availability_30 availability_60
# 0                  NaN                t              13              35
# 1                  NaN                t              29              42
# 2                  NaN                t              29              54
# 3                  NaN                t               4              10
# 4                  NaN                t              30              41
# ...                ...              ...             ...             ...
# 14868              NaN                t              10              36
# 14869              NaN                t              20              20
# 14870              NaN                t              30              60
# 14871              NaN                t              15              42
# 14872              NaN                t              24              51
#
# [14873 rows x 52 columns]

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                          0
# id                                  0
# listing_url                         0
# last_scraped                        0
# source                              0
# name                                0
# description                         0
# neighborhood_overview               8
# picture_url                         0
# host_id                             0
# host_url                            0
# host_name                           0
# host_since                          0
# host_location                       2
# host_about                          0
# host_response_time                  0
# host_response_rate                  0
# host_acceptance_rate                0
# host_is_superhost                   0
# host_thumbnail_url                  0
# host_picture_url                    0
# host_neighbourhood                  8
# host_listings_count                 0
# host_total_listings_count           0
# host_verifications                  0
# host_has_profile_pic                0
# host_identity_verified              0
# neighbourhood                       8
# neighbourhood_cleansed              0
# neighbourhood_group_cleansed        0
# latitude                            0
# longitude                           0
# property_type                       0
# room_type                           0
# accommodates                        0
# bathrooms_text                      0
# bedrooms                            0
# beds                                0
# amenities                           0
# price                               0
# minimum_nights                      0
# maximum_nights                      0
# minimum_minimum_nights              0
# maximum_minimum_nights              0
# minimum_maximum_nights              0
# maximum_maximum_nights              0
# minimum_nights_avg_ntm              0
# maximum_nights_avg_ntm              0
# calendar_updated                14873
# has_availability                    0
# availability_30                     0
# availability_60                     0
# dtype: int64

# %%
cuantitativas = data1.iloc[:, 1:]
cualitativas = data1.iloc[:, [0]]
y = cuantitativas.select_dtypes(include=[np.number]).copy() ##numéricas para los cálculos

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe

plt.figure(figsize=(15, 8))
y.plot(kind="box", vert=False)
plt.title("Valores Atípicos de mi base de datos 'albany'")
plt.show()

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
#ejemplo valores atipicos
##y=cuantitativas
##Limite_Superior= y.mean() + 3*y.std()
##Limite_Inferior= y.mean() - 3*y.std()
#print("Limite superior permitido", Limite_Superior)
#print("Limite inferior permitido", Limite_Inferior)

#solo numéricas:
y = cuantitativas.select_dtypes(include=[float, int]).copy()

Limite_Superior = y.mean(numeric_only=True) + 3*y.std(numeric_only=True)
Limite_Inferior = y.mean(numeric_only=True) - 3*y.std(numeric_only=True)

print("Límite superior permitido:\n", Limite_Superior)
print("Límite inferior permitido:\n", Limite_Inferior)
# Out:
# Límite superior permitido:
#  id                           2.198169e+18
# host_id                      8.772330e+08
# host_listings_count          3.505732e+02
# host_total_listings_count    6.621859e+02
# latitude                     4.135762e+01
# longitude                   -8.427323e+00
# accommodates                 1.006399e+01
# bedrooms                     5.251723e+00
# beds                         7.574478e+00
# minimum_nights               9.575237e+01
# maximum_nights               1.866144e+03
# minimum_minimum_nights       7.118708e+01
# maximum_minimum_nights       1.216046e+02
# minimum_maximum_nights       2.040373e+03
# maximum_maximum_nights       2.137070e+03
# minimum_nights_avg_ntm       7.534557e+01
# maximum_nights_avg_ntm       2.010336e+03
# calendar_updated                      NaN
# availability_30              3.775731e+01
# availability_60              7.886268e+01
# dtype: float64
# Límite inferior permitido:
#  id                          -1.117431e+18
# host_id                     -3.917382e+08
# host_listings_count         -2.722737e+02
# host_total_listings_count   -5.501208e+02
# latitude                     4.094908e+01
# longitude                   -8.798985e+00
# accommodates                -2.800760e+00
# bedrooms                    -2.338255e+00
# beds                        -3.126149e+00
# minimum_nights              -8.795744e+01
# maximum_nights              -8.444731e+02
# minimum_minimum_nights      -6.485104e+01
# maximum_minimum_nights      -1.074226e+02
# minimum_maximum_nights      -9.551890e+02
# maximum_maximum_nights      -7.303875e+02
# minimum_nights_avg_ntm      -6.765066e+01
# maximum_nights_avg_ntm      -8.153312e+02
# calendar_updated                      NaN
# availability_30             -1.696594e+01
# availability_60             -3.190604e+01
# dtype: float64

# %%
#Dejo NaN donde se salen de los límites
data3 = y[(y <= Limite_Superior) & (y >= Limite_Inferior)]
data3
#Relleno los nan con el promedio y redondeo a 1
data_clean = data3.fillna(round(data3.mean(), 1))
data_clean
# Out:
#                         id    host_id  host_listings_count  \
# 0                    41339     180050                 26.0
# 1                    55111     259711                  3.0
# 2                    73828     259711                  3.0
# 3                    87873     480980                  4.0
# 4                    94701     505473                  1.0
# ...                    ...        ...                  ...
# 14868  1442944169953064519  695687907                  3.0
# 14869  1442949312063381006  695687907                  3.0
# 14870  1442972095274896534  110938864                  2.0
# 14871  1443457123327763296  452918929                114.0
# 14872  1443457546151071185  452918929                114.0
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# 0                           30.0  41.150100  -8.660350           5.0
# 1                            3.0  41.174180  -8.600000           5.0
# 2                            3.0  41.176220  -8.600000           5.0
# 3                            6.0  41.156070  -8.604370           4.0
# 4                            7.0  41.146750  -8.601860           3.0
# ...                          ...        ...        ...           ...
# 14868                        4.0  41.190834  -8.597960           2.0
# 14869                        4.0  41.190121  -8.596165           2.0
# 14870                        2.0  41.158620  -8.635020           4.0
# 14871                      116.0  41.147928  -8.606483           6.0
# 14872                      116.0  41.149712  -8.608559           6.0
#
#        bedrooms  beds  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0           1.0   3.0             2.0             240                     2.0
# 1           2.0   4.0             5.0              28                     5.0
# 2           2.0   4.0             5.0              28                     5.0
# 3           2.0   2.0             3.0              15                     3.0
# 4           1.0   1.0             3.0             365                     3.0
# ...         ...   ...             ...             ...                     ...
# 14868       1.0   1.0             1.0             365                     1.0
# 14869       1.0   2.0             1.0             365                     1.0
# 14870       2.0   3.0             1.0             365                     1.0
# 14871       2.0   4.0             1.0            1125                     1.0
# 14872       2.0   4.0             1.0            1125                     1.0
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                         2.0                  1125.0                  1125.0
# 1                         7.0                    28.0                    28.0
# 2                         5.0                    28.0                    28.0
# 3                         3.0                    15.0                    15.0
# 4                         7.0                  1125.0                  1125.0
# ...                       ...                     ...                     ...
# 14868                     1.0                   365.0                   365.0
# 14869                     1.0                   365.0                   365.0
# 14870                     1.0                   365.0                   365.0
# 14871                     2.0                  1125.0                  1125.0
# 14872                     2.0                  1125.0                  1125.0
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                         2.0                  1125.0               NaN
# 1                         5.1                    28.0               NaN
# 2                         5.0                    28.0               NaN
# 3                         3.0                    15.0               NaN
# 4                         3.7                  1125.0               NaN
# ...                       ...                     ...               ...
# 14868                     1.0                   365.0               NaN
# 14869                     1.0                   365.0               NaN
# 14870                     1.0                   365.0               NaN
# 14871                     2.0                  1125.0               NaN
# 14872                     2.0                  1125.0               NaN
#
#        availability_30  availability_60
# 0                   13               35
# 1                   29               42
# 2                   29               54
# 3                    4               10
# 4                   30               41
# ...                ...              ...
# 14868               10               36
# 14869               20               20
# 14870               30               60
# 14871               15               42
# 14872               24               51
#
# [14873 rows x 20 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# id                               0
# host_id                          0
# host_listings_count              0
# host_total_listings_count        0
# latitude                         0
# longitude                        0
# accommodates                     0
# bedrooms                         0
# beds                             0
# minimum_nights                   0
# maximum_nights                   0
# minimum_minimum_nights           0
# maximum_minimum_nights           0
# minimum_maximum_nights           0
# maximum_maximum_nights           0
# minimum_nights_avg_ntm           0
# maximum_nights_avg_ntm           0
# calendar_updated             14873
# availability_30                  0
# availability_60                  0
# dtype: int64

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y = cuantitativas.select_dtypes(include=[float, int]).copy()

percentile25 = y.quantile(0.25, numeric_only=True)   # Q1
percentile75 = y.quantile(0.75, numeric_only=True)   # Q3
iqr = percentile75 - percentile25

Limite_Superior_iqr = percentile75 + 1.5*iqr
Limite_Inferior_iqr = percentile25 - 1.5*iqr
print("Límite superior permitido:\n", Limite_Superior_iqr)
print("Límite inferior permitido:\n", Limite_Inferior_iqr)
# Out:
# Límite superior permitido:
#  id                           2.682989e+18
# host_id                      1.029614e+09
# host_listings_count          4.700000e+01
# host_total_listings_count    5.450000e+01
# latitude                     4.117765e+01
# longitude                   -8.580325e+00
# accommodates                 7.000000e+00
# bedrooms                     3.500000e+00
# beds                         6.000000e+00
# minimum_nights               3.500000e+00
# maximum_nights               2.722500e+03
# minimum_minimum_nights       3.500000e+00
# maximum_minimum_nights       4.500000e+00
# minimum_maximum_nights       2.766000e+03
# maximum_maximum_nights       2.265000e+03
# minimum_nights_avg_ntm       5.000000e+00
# maximum_nights_avg_ntm       2.542500e+03
# calendar_updated                      NaN
# availability_30              3.550000e+01
# availability_60              8.050000e+01
# dtype: float64
# Límite inferior permitido:
#  id                          -1.609794e+18
# host_id                     -5.422623e+08
# host_listings_count         -2.500000e+01
# host_total_listings_count   -2.950000e+01
# latitude                     4.112384e+01
# longitude                   -8.645005e+00
# accommodates                -1.000000e+00
# bedrooms                    -5.000000e-01
# beds                        -2.000000e+00
# minimum_nights              -5.000000e-01
# maximum_nights              -1.537500e+03
# minimum_minimum_nights      -5.000000e-01
# maximum_minimum_nights       5.000000e-01
# minimum_maximum_nights      -1.610000e+03
# maximum_maximum_nights      -7.750000e+02
# minimum_nights_avg_ntm      -6.000000e-01
# maximum_nights_avg_ntm      -1.237500e+03
# calendar_updated                      NaN
# availability_30             -1.650000e+01
# availability_60             -3.550000e+01
# dtype: float64

# %%
data3_iqr = y[(y <= Limite_Superior_iqr) & (y >= Limite_Inferior_iqr)]
data4 = data3_iqr.fillna(round(data3_iqr.median(numeric_only=True), 1))
data3_iqr
# Out:
#                         id    host_id  host_listings_count  \
# 0                    41339     180050                 26.0
# 1                    55111     259711                  3.0
# 2                    73828     259711                  3.0
# 3                    87873     480980                  4.0
# 4                    94701     505473                  1.0
# ...                    ...        ...                  ...
# 14868  1442944169953064519  695687907                  3.0
# 14869  1442949312063381006  695687907                  3.0
# 14870  1442972095274896534  110938864                  2.0
# 14871  1443457123327763296  452918929                  NaN
# 14872  1443457546151071185  452918929                  NaN
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# 0                           30.0  41.150100        NaN           5.0
# 1                            3.0  41.174180        NaN           5.0
# 2                            3.0  41.176220        NaN           5.0
# 3                            6.0  41.156070  -8.604370           4.0
# 4                            7.0  41.146750  -8.601860           3.0
# ...                          ...        ...        ...           ...
# 14868                        4.0        NaN  -8.597960           2.0
# 14869                        4.0        NaN  -8.596165           2.0
# 14870                        2.0  41.158620  -8.635020           4.0
# 14871                        NaN  41.147928  -8.606483           6.0
# 14872                        NaN  41.149712  -8.608559           6.0
#
#        bedrooms  beds  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0           1.0   3.0             2.0             240                     2.0
# 1           2.0   4.0             NaN              28                     NaN
# 2           2.0   4.0             NaN              28                     NaN
# 3           2.0   2.0             3.0              15                     3.0
# 4           1.0   1.0             3.0             365                     3.0
# ...         ...   ...             ...             ...                     ...
# 14868       1.0   1.0             1.0             365                     1.0
# 14869       1.0   2.0             1.0             365                     1.0
# 14870       2.0   3.0             1.0             365                     1.0
# 14871       2.0   4.0             1.0            1125                     1.0
# 14872       2.0   4.0             1.0            1125                     1.0
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                         2.0                  1125.0                  1125.0
# 1                         NaN                    28.0                    28.0
# 2                         NaN                    28.0                    28.0
# 3                         3.0                    15.0                    15.0
# 4                         NaN                  1125.0                  1125.0
# ...                       ...                     ...                     ...
# 14868                     1.0                   365.0                   365.0
# 14869                     1.0                   365.0                   365.0
# 14870                     1.0                   365.0                   365.0
# 14871                     2.0                  1125.0                  1125.0
# 14872                     2.0                  1125.0                  1125.0
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                         2.0                  1125.0               NaN
# 1                         NaN                    28.0               NaN
# 2                         5.0                    28.0               NaN
# 3                         3.0                    15.0               NaN
# 4                         3.7                  1125.0               NaN
# ...                       ...                     ...               ...
# 14868                     1.0                   365.0               NaN
# 14869                     1.0                   365.0               NaN
# 14870                     1.0                   365.0               NaN
# 14871                     2.0                  1125.0               NaN
# 14872                     2.0                  1125.0               NaN
#
#        availability_30  availability_60
# 0                   13               35
# 1                   29               42
# 2                   29               54
# 3                    4               10
# 4                   30               41
# ...                ...              ...
# 14868               10               36
# 14869               20               20
# 14870               30               60
# 14871               15               42
# 14872               24               51
#
# [14873 rows x 20 columns]

# %%
valores_nulos=data3_iqr.isnull().sum()
valores_nulos
# Out:
# id                               0
# host_id                          0
# host_listings_count           2365
# host_total_listings_count     2380
# latitude                      2865
# longitude                     2927
# accommodates                   884
# bedrooms                       757
# beds                           360
# minimum_nights                1144
# maximum_nights                   0
# minimum_minimum_nights         929
# maximum_minimum_nights        1917
# minimum_maximum_nights           3
# maximum_maximum_nights           3
# minimum_nights_avg_ntm         852
# maximum_nights_avg_ntm           3
# calendar_updated             14873
# availability_30                  0
# availability_60                  0
# dtype: int64

# %%
data4_iqr=data3_iqr.copy()
data4_iqr=data4_iqr.fillna(round(data3_iqr.median(),1))
data4_iqr
# Out:
#                         id    host_id  host_listings_count  \
# 0                    41339     180050                 26.0
# 1                    55111     259711                  3.0
# 2                    73828     259711                  3.0
# 3                    87873     480980                  4.0
# 4                    94701     505473                  1.0
# ...                    ...        ...                  ...
# 14868  1442944169953064519  695687907                  3.0
# 14869  1442949312063381006  695687907                  3.0
# 14870  1442972095274896534  110938864                  2.0
# 14871  1443457123327763296  452918929                  4.0
# 14872  1443457546151071185  452918929                  4.0
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# 0                           30.0  41.150100  -8.600000           5.0
# 1                            3.0  41.174180  -8.600000           5.0
# 2                            3.0  41.176220  -8.600000           5.0
# 3                            6.0  41.156070  -8.604370           4.0
# 4                            7.0  41.146750  -8.601860           3.0
# ...                          ...        ...        ...           ...
# 14868                        4.0  41.100000  -8.597960           2.0
# 14869                        4.0  41.100000  -8.596165           2.0
# 14870                        2.0  41.158620  -8.635020           4.0
# 14871                        5.0  41.147928  -8.606483           6.0
# 14872                        5.0  41.149712  -8.608559           6.0
#
#        bedrooms  beds  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0           1.0   3.0             2.0             240                     2.0
# 1           2.0   4.0             2.0              28                     1.0
# 2           2.0   4.0             2.0              28                     1.0
# 3           2.0   2.0             3.0              15                     3.0
# 4           1.0   1.0             3.0             365                     3.0
# ...         ...   ...             ...             ...                     ...
# 14868       1.0   1.0             1.0             365                     1.0
# 14869       1.0   2.0             1.0             365                     1.0
# 14870       2.0   3.0             1.0             365                     1.0
# 14871       2.0   4.0             1.0            1125                     1.0
# 14872       2.0   4.0             1.0            1125                     1.0
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                         2.0                  1125.0                  1125.0
# 1                         2.0                    28.0                    28.0
# 2                         2.0                    28.0                    28.0
# 3                         3.0                    15.0                    15.0
# 4                         2.0                  1125.0                  1125.0
# ...                       ...                     ...                     ...
# 14868                     1.0                   365.0                   365.0
# 14869                     1.0                   365.0                   365.0
# 14870                     1.0                   365.0                   365.0
# 14871                     2.0                  1125.0                  1125.0
# 14872                     2.0                  1125.0                  1125.0
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                         2.0                  1125.0               NaN
# 1                         2.0                    28.0               NaN
# 2                         5.0                    28.0               NaN
# 3                         3.0                    15.0               NaN
# 4                         3.7                  1125.0               NaN
# ...                       ...                     ...               ...
# 14868                     1.0                   365.0               NaN
# 14869                     1.0                   365.0               NaN
# 14870                     1.0                   365.0               NaN
# 14871                     2.0                  1125.0               NaN
# 14872                     2.0                  1125.0               NaN
#
#        availability_30  availability_60
# 0                   13               35
# 1                   29               42
# 2                   29               54
# 3                    4               10
# 4                   30               41
# ...                ...              ...
# 14868               10               36
# 14869               20               20
# 14870               30               60
# 14871               15               42
# 14872               24               51
#
# [14873 rows x 20 columns]

# %%
Datos_limpios = pd.concat([cualitativas, data4_iqr], axis=1)
Datos_limpios
# Out:
#        Unnamed: 0                   id    host_id  host_listings_count  \
# 0               0                41339     180050                 26.0
# 1               1                55111     259711                  3.0
# 2               2                73828     259711                  3.0
# 3               3                87873     480980                  4.0
# 4               4                94701     505473                  1.0
# ...           ...                  ...        ...                  ...
# 14868       14868  1442944169953064519  695687907                  3.0
# 14869       14869  1442949312063381006  695687907                  3.0
# 14870       14870  1442972095274896534  110938864                  2.0
# 14871       14871  1443457123327763296  452918929                  4.0
# 14872       14872  1443457546151071185  452918929                  4.0
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# 0                           30.0  41.150100  -8.600000           5.0
# 1                            3.0  41.174180  -8.600000           5.0
# 2                            3.0  41.176220  -8.600000           5.0
# 3                            6.0  41.156070  -8.604370           4.0
# 4                            7.0  41.146750  -8.601860           3.0
# ...                          ...        ...        ...           ...
# 14868                        4.0  41.100000  -8.597960           2.0
# 14869                        4.0  41.100000  -8.596165           2.0
# 14870                        2.0  41.158620  -8.635020           4.0
# 14871                        5.0  41.147928  -8.606483           6.0
# 14872                        5.0  41.149712  -8.608559           6.0
#
#        bedrooms  beds  ...  maximum_nights  minimum_minimum_nights  \
# 0           1.0   3.0  ...             240                     2.0
# 1           2.0   4.0  ...              28                     1.0
# 2           2.0   4.0  ...              28                     1.0
# 3           2.0   2.0  ...              15                     3.0
# 4           1.0   1.0  ...             365                     3.0
# ...         ...   ...  ...             ...                     ...
# 14868       1.0   1.0  ...             365                     1.0
# 14869       1.0   2.0  ...             365                     1.0
# 14870       2.0   3.0  ...             365                     1.0
# 14871       2.0   4.0  ...            1125                     1.0
# 14872       2.0   4.0  ...            1125                     1.0
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                         2.0                  1125.0                  1125.0
# 1                         2.0                    28.0                    28.0
# 2                         2.0                    28.0                    28.0
# 3                         3.0                    15.0                    15.0
# 4                         2.0                  1125.0                  1125.0
# ...                       ...                     ...                     ...
# 14868                     1.0                   365.0                   365.0
# 14869                     1.0                   365.0                   365.0
# 14870                     1.0                   365.0                   365.0
# 14871                     2.0                  1125.0                  1125.0
# 14872                     2.0                  1125.0                  1125.0
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                         2.0                  1125.0               NaN
# 1                         2.0                    28.0               NaN
# 2                         5.0                    28.0               NaN
# 3                         3.0                    15.0               NaN
# 4                         3.7                  1125.0               NaN
# ...                       ...                     ...               ...
# 14868                     1.0                   365.0               NaN
# 14869                     1.0                   365.0               NaN
# 14870                     1.0                   365.0               NaN
# 14871                     2.0                  1125.0               NaN
# 14872                     2.0                  1125.0               NaN
#
#        availability_30  availability_60
# 0                   13               35
# 1                   29               42
# 2                   29               54
# 3                    4               10
# 4                   30               41
# ...                ...              ...
# 14868               10               36
# 14869               20               20
# 14870               30               60
# 14871               15               42
# 14872               24               51
#
# [14873 rows x 21 columns]

# %%
valores_nulos=Datos_limpios.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                       0
# id                               0
# host_id                          0
# host_listings_count              0
# host_total_listings_count        0
# latitude                         0
# longitude                        0
# accommodates                     0
# bedrooms                         0
# beds                             0
# minimum_nights                   0
# maximum_nights                   0
# minimum_minimum_nights           0
# maximum_minimum_nights           0
# minimum_maximum_nights           0
# maximum_maximum_nights           0
# minimum_nights_avg_ntm           0
# maximum_nights_avg_ntm           0
# calendar_updated             14873
# availability_30                  0
# availability_60                  0
# dtype: int64

# %%
Datos_limpios['calendar_updated'] = Datos_limpios['calendar_updated'].fillna('Sin actualización')
#Volvemos a corroborar y listo ya no tenemos valores nulos
valores_nulos=Datos_limpios.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                   0
# id                           0
# host_id                      0
# host_listings_count          0
# host_total_listings_count    0
# latitude                     0
# longitude                    0
# accommodates                 0
# bedrooms                     0
# beds                         0
# minimum_nights               0
# maximum_nights               0
# minimum_minimum_nights       0
# maximum_minimum_nights       0
# minimum_maximum_nights       0
# maximum_maximum_nights       0
# minimum_nights_avg_ntm       0
# maximum_nights_avg_ntm       0
# calendar_updated             0
# availability_30              0
# availability_60              0
# dtype: int64

# %%
data1.to_csv("Pais_sin_nulos.csv", index=False)
data3.to_csv("Pais_outliers_STD_filtrado.csv", index=False)
data_clean.to_csv("Pais_outliers_STD.csv", index=False)
data3_iqr.to_csv("Pais_outliers_IQR_filtrado.csv", index=False)
data4.to_csv("Pais_outliers_IQR.csv", index=False)
